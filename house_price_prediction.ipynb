# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Uncover Real Estate Gold: Revealing House Sale Price Secrets**
#
# Estimated time needed: **30** minutes
#
# **Welcome to the world of data-driven real estate, where mystery and numbers intertwine!**
#
# 🌟 **The Mission:** You're a data detective, and your quest is to predict the prices of houses in a vibrant, ever-changing market. But it's not just about predicting; it's about understanding the 'why' behind the 'how much'.
#
# 🌲 **The Tool - Random Forest:** Imagine a deep forest, not of trees, but of decisions. Each tree in this 'Random Forest' holds secrets about house prices. They work together, combining their knowledge to predict prices with stunning accuracy. It's a forest that grows stronger with each piece of data!
#
# 🧩 **The Interpreter - SHAP Analysis:** But what's a prediction without understanding? Enter SHAP, your magnifying glass for the data world. It helps you peek behind the curtain of the Random Forest's decisions, revealing which factors - be it location, size, or the number of crystal chandeliers - influence house prices the most.
#
# 📊 **The Journey:** You'll embark on an adventure through datasets, wrangling numbers, and weaving through variables. You'll train your Random Forest, watch it make predictions, and then use SHAP to decode its wisdom.
#
# 🔮 **The Goal:** By the end of your project, not only will you predict house prices with impressive accuracy, but you'll also identify the most influential factors driving those prices. Is it the charm of a backyard garden, the allure of a marble countertop, or the convenience of a nearby metro station?
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-GPXX0GJDEN/house.png" width="600px" alt="houseworld">

# %% [markdown]
# # __Table of Contents__
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="#Importing-Required-Libraries">Importing Required Libraries</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Background">Background</a>
#         <ol>
#             <li><a href="#Understanding House Price Prediction">Understanding House Price Prediction</a></li>
#             <li><a href="#Role of Machine Learning in this Project">Role of Machine Learning in this Project</a></li>
#             <li><a href="#Understanding House Price Prediction">Incorporating SHAP for Explainability</a></li>
#             <li><a href="#Project Significance">Project Significance</a></li>
#         </ol>
#     </li>
#     <li><a href="#Build Model To Predict House Prices">Build Model To Predict House Prices</a></li>
#     <li><a href="#Using SHAP to explain the model">Using SHAP to explain the model</a></li>
#     <li>
#         <a href="#Exercises">Exercises</a>
#         <ol>
#             <li><a href="#Exercise 1 - Show the house 3 or more bedrooms">Exercise 1 - Show the house 3 or more bedrooms</a></li>
#             <li><a href="#Exercise 2 - Set different parameters">Exercise 2 - Set different parameters</a></li>
#             <li><a href="#Exercise 3 - Change the estimator to XGboost">Exercise 3 - Change the estimator to XGboost</a></li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # Objectives
#
# After completing this lab you will be able to:
#
#  - Develop a predictive model using the Random Forest algorithm that accurately forecasts house prices based on a range of features.
#  - Demploy SHAP analysis to interpret the Random Forest model, providing insights into how different variables influence the prediction of house prices.
#  - Identify and rank the most significant factors affecting house sales prices through comprehensive SHAP value analysis.

# %% [markdown]
# ---

# %% [markdown]
# # Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for managing the data.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for mathematical operations.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for machine learning and machine-learning-pipeline related functions.
# *   [`seaborn`](https://seaborn.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for visualizing the data.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for additional plotting tools.
# *   [`shap`](https://shap.readthedocs.io/en/latest/) for explain the model.

# %% [markdown]
# ### Installing Required Libraries
#
# The following required libraries are pre-installed in the Skills Network Labs environment. However, if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda), you will need to install these libraries by removing the `#` sign before `!pip` in the code cell below.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !pip install -qy pandas==1.3.4 numpy==1.21.4 seaborn==0.9.0 matplotlib==3.5.0 scikit-learn==0.20.1
# - Update a specific package
# !pip install pmdarima -U
# - Update a package to specific version
# !pip install --upgrade pmdarima==2.0.2
# Note: If your environment doesn't support "!pip install", use "!mamba install"

# %% [markdown]
# The following required libraries are __not__ pre-installed in the Skills Network Labs environment. __You will need to run the following cell__ to install them:

# %%
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 545.7/545.7 kB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 39.3 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 45.2 MB/s eta 0:00:0000:0100:01
# ...

# %% [markdown]
# ### Importing Required Libraries
#
# _We recommend you import all required libraries in one place (here):_

# %%
from tqdm import tqdm
import numpy as np
import pandas as pd
from itertools import accumulate
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import r2_score
import skillsnetwork
import shap

# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

sns.set_context('notebook')
sns.set_style('white')
warn()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/utils/validation.py:37: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LARGE_SPARSE_SUPPORTED = LooseVersion(scipy_version) >= '0.14.0'
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ._gradient_boosting import predict_stages
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Background
#
# ## Understanding House Price Prediction
# - **Objective**: Predict the selling prices of houses based on various features like location, size, age, etc.
# - **Importance**: Accurate predictions help buyers and sellers make informed decisions, and assist real estate agents and economists in market analysis.
#
# ## Role of Machine Learning in this Project
# - **Machine Learning in Real Estate**: Utilizes historical data to forecast future prices, making predictions more accurate and reliable.
# - **Random Forest Algorithm**:
#   - **Type**: A popular, power machine learning model.
#   - **Working Principle**: Builds multiple decision trees and merges them to get a more accurate and stable prediction.
#   - **Advantages**: Handles a large number of features, works well with non-linear data, and provides feature importance.
#
# ## Incorporating SHAP for Explainability
# - **SHAP (SHapley Additive exPlanations)**:
#   - **Purpose**: Explains the output of machine learning models.
#   - **Methodology**: Uses game theory approach to assign each feature an importance value (shap value) for a particular prediction.
# - **Benefits of SHAP in the Project**:
#   - **Transparency**: Helps understand why the model made a specific prediction.
#   - **Insightful**: Identifies which features are most influential in determining house prices.
#   - **Trustworthy**: Makes the model's decisions interpretable to humans, increasing trust and usability.
#
# ## Project Significance
# - **Combining Prediction with Explanation**: Not just predicting prices, but also providing insights into what drives those prices.
# - **Decision Making**: Assists stakeholders in understanding the market dynamics and making evidence-based decisions.
# - **Advancing Real Estate Analytics**: Represents a step forward in applying advanced analytics in real estate.

# %% [markdown]
# ---

# %% [markdown]
# # Build Model To Predict House Prices
#
# ### Task Overview
#
# ### 1. Building the Random Forest Model for House Price Prediction
#
# - **Data Collection**: Acquire historical data on house sales, including features like location, size, age, amenities, and more. Data can be found from [kaggle](https://www.kaggle.com/datasets/harlfoxem/housesalesprediction/data). <br>
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-GPXX0GJDEN/real%20estate%20investment%20growth.png" width="400px" alt="house card"> <br>
#
# - **Data Preprocessing**:
#   - **Data Inspection**: Examine the dataset to understand its structure, content, and characteristics. This includes checking data features, types, and missing values.
#   - **Distribution Analysis**: Plot the distribution of the sales price to understand its spread and identify any patterns or outliers.
# - **Model Development**:
#   - **Training the Random Forest Model**: Use the prepared dataset to train the model.
#   - **Model Tuning**: Use grid search to adjust parameters to find the most effective model configuration.
# - **Model Evaluation**:
#   - **Validation Techniques**: Use methods cross-validation to assess the model's performance.
#   - **Performance Metrics**: R² Score.
#
# ### 2. Using SHAP for Model Explanation
#
# - **SHAP Value Calculation**:
#   - **Integration with Random Forest**: Calculate SHAP values for predictions made by the Random Forest model.
#   - **Feature Importance Analysis**: Determine which features most significantly impact house prices.
# - **Interpretation of SHAP Values**:
#   - **Visualizations**: Use plots like SHAP value charts, dependency plots, and summary plots to visualize the impact of features.
#   - **Insight Extraction**: Analyze SHAP values to extract meaningful insights about how different features influence house price predictions.

# %% [markdown]
# ### Dataset description
#
# This dataset contains house sale prices for King County, which includes Seattle. It includes homes sold between May 2014 and May 2015. <br>
#
# It's a great dataset for evaluating simple regression models.
#
# - **Id**: Unique ID for each home sold
# - **Date**: Date of the home sale
# - **Price**: Price of each home sold
# - **Bedrooms**: Number of bedrooms
# - **Bathrooms**: Number of bathrooms, where .5 accounts for a room with a toilet but no shower
# - **Sqft_living**: Square footage of the apartments interior living space
# - **Sqft_lot**: Square footage of the land space
# - **Floors**: Number of floors
# - **Waterfront**: A dummy variable for whether the apartment was overlooking the waterfront or not
# - **View**: An index from 0 to 4 of how good the view of the property was
# - **Condition**: An index from 1 to 5 on the condition of the apartment
# - **Grade**: An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design
# - **Sqft_above**: The square footage of the interior housing space that is above ground level
# - **Sqft_basement**: The square footage of the interior housing space that is below ground level
# - **Yr_built**: The year the house was initially built
# - **Yr_renovated**: The year of the house's last renovation
# - **Zipcode**: What zipcode area the house is in
# - **Lat**: Latitude
# - **Long**: Longitude
# - **Sqft_living15**: The square footage of interior housing living space for the nearest 15 neighbors
# - **Sqft_lot15**: The square footage of the land lots of the nearest 15 neighbors

# %% [markdown]
# ### Prepare dataset

# %% [markdown]
# #### Import data

# %%
await skillsnetwork.download_dataset('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-GPXX0GJDEN/kc_house_data.csv')
df = pd.read_csv('kc_house_data.csv')
# Out:
# ...
# Saved as 'kc_house_data.csv'

# %% [markdown]
# #### Take a look at dataset
# Using function `sample(x)` to randomly show x numbers of samples

# %%
df.sample(5)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 13206  2026049183  20150402T000000  324950.0         2        1.5
# 17624  2310110230  20140520T000000  329900.0         3        2.5
# 5921   7802900380  20140908T000000  335000.0         2        1.0
# 19155  7227800040  20140604T000000  190000.0         5        2.0
# 11312  3235100075  20150503T000000  279000.0         3        1.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 13206         1230      1516     3.0           0     0  ...      8
# 17624         2170      4905     2.0           0     0  ...      8
# 5921          1360     69260     1.0           0     0  ...      5
# 19155         1750     10284     1.0           0     0  ...      5
# 11312         1010      7903     1.0           0     0  ...      6
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 13206        1230              0      2000             0    98125  47.7265
# ...

# %% [markdown]
# #### Drop the column **Id** in the dataset
# As columns **Id**, **date**  will not be used in the analysis, we drop it using function `drop()`.
# - `axis=1` indicates that it is dropping column instead of a row.
# - `inplace=True` indicates that we modify the dataframe itself instead of creating a new one.

# %%
df.drop('id', axis=1, inplace=True)
df.drop('date', axis=1, inplace=True)

# %% [markdown]
# We can inspect the types of feature columns using the following code:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  float64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  sqft_above     21613 non-null  int64
#  11  sqft_basement  21613 non-null  int64
#  12  yr_built       21613 non-null  int64
#  13  yr_renovated   21613 non-null  int64
#  14  zipcode        21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
# ...

# %% [markdown]
# Plot house price distribution, we see house

# %%
plt.figure(figsize=(6, 4))
sns.distplot(df['price'], color='b', bins=100, hist_kws={'alpha': 0.4});

# %% [markdown]
# ### Data Spliting
# In order to conduct the supervised learning, we need to split data to get X_train, X_test, y_train, y_test

# %%
X = df.drop(columns = ['price'])
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %% [markdown]
# ### Modeling

# %% [markdown]
# #### Set parameters for the model

# %%
param_randomf = {
    'n_estimators' : [100, 200],
    'max_depth': [10, 20]
}

# %% [markdown]
# Using `GridSearchCV` function from scikit-learn for hyperparameter tuning. Let's break down the code here. <br>
# - `estimator=RandomForestRegressor()`: Here, RandomForestRegressor is set as the estimator for the grid search. This means that the grid search will be tuning a Random Forest regression model.
# - `param_grid=param_randomf`: The param_grid specifies the parameters, which will use the parameters set in `param_randomf`.
# - `cv=5`: This indicates that 5-fold cross-validation is used. In cross-validation, the dataset is divided into 'k' parts (in this case, 5 parts). The model is trained on 'k-1' parts and validated on the remaining part. <br><br>
# It might take around 3~5 minutes. Let's take a break.

# %%
grid_search = GridSearchCV(estimator=RandomForestRegressor(), param_grid=param_randomf, cv=5)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'n_estimators': [100, 200], 'max_depth': [10, 20]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %% [markdown]
# After fits the Random Forest model to the training data, trying out all the different combinations of parameter values specified in `param_randomf`, we can get a best model.

# %%
best_model = grid_search.best_estimator_

# %% [markdown]
# We can take a look at the best parameters

# %%
best_params = grid_search.best_estimator_
best_params
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# Using best model to test on the X_test dataset and get the results of prediction.

# %%
y_pred = best_model.predict(X_test)

# %% [markdown]
# Using metric R² to present the performance of the model.
# - `r2_score`: This function comes from scikit-learn. It is used to calculate the R² score, which is a statistical measure of how close the data are to the fitted regression line. In simpler terms, it measures how well the regression predictions approximate the real data points.
# - The R² score is a number between 0 and 1, where a score closer to 1 indicates that the model's predictions are very close to the actual values.

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.8599236785162399

# %% [markdown]
# From the observed results, given the current parameter settings, it is evident that the R² score is approximately 0.859. This score suggests a strong performance of the regression model in the given task.

# %% [markdown]
# ---

# %% [markdown]
# # Using SHAP to explain the model

# %% [markdown]
# Create a subset of training data (100 samples). Computing SHAP values for the features in `X_sample`, as if we use whole dataset, it will take significant time for shap to process. Of course you can set more data or even whole traing data.
# - Using `shap.Explainer` to explain the `best model` we get previously on `X_sample`
# - Using  `shap_values` variable to hold the SHAP values computed by the explainer. These values can be used to understand how each feature in the data contributes to each prediction made by your model.

# %%
X_sample = X_train.sample(100)
explainer = shap.Explainer(best_model, X_sample)
shap_values = explainer(X_sample)
# Out:
#  97%|=================== | 97/100 [00:15<00:00]

# %% [markdown]
# Using beeswarm plot to show shap_values.

# %%
shap.plots.beeswarm(shap_values)

# %% [markdown]
# The bee-swarm plot of the SHAP values offers valuable insights into the factors that influence house selling prices.
# - The vertical axis placement indicates the magnitude of effect a feature has on the price.
# - The horizontal axis represents the direction of the effect: values to the left decrease the price, while values to the right increase it.
# - Each data point is represented as a dot or bee along the horizontal axis. Using colour to indicating its value within the specified feature (red indicates high values, while blue represents low values).
#
#
# Key observations include:
# - Location is the most critical determinant of house prices.
# - The living area size, especially the square footage, is a significant predictor of price, with larger areas boosting the predicted value.
# - The property's grade and age are also influential, with older properties generally reducing the predicted selling price.
# - Additional factors such as the number of bedrooms and basement size, along with seven other attributes, have a comparatively minor effect on pricing.

# %% [markdown]
# We also can see how each feature's influence to house price prediction using `force_plot` in SHAP.

# %%
shap.initjs()
shap.plots.force(shap_values)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# Let's examine an example using the output plot. Once the plot is generated, set the y-axis to represent the effects of sqft_living, and the x-axis to display sqft_living values. This setup allows us to observe the specific points at which sqft_living has either a positive or negative impact on the model.
#
# - Notably, a sqft_living value of approximately 2000 serves as a pivotal threshold. Values greater than 2000 sqft_living tend to have a positive influence, while those less than 2000 exhibit a negative impact.

# %% [markdown]
# Take away points both house sellers or buyers
#
# - **Location is Key**: The location of a property is one of the most significant determinants of its value. Buyers should prioritize location based on their lifestyle needs and future resale value, while sellers should highlight the benefits of their property's location.
#
# - **Size Matters, Especially Living Space**: The square footage of the living area is a major price influencer. Buyers should consider their space requirements carefully, and sellers should emphasize the spaciousness and layout of living areas.
#
# - **Age and Condition of the Property**: Newer properties often fetch higher prices. Sellers with older properties should consider upgrades or renovations to improve value. Buyers should assess the age and condition of the property in terms of potential future maintenance and upgrade costs.
#
# - **Property Grade and Features**: The overall grade of the property, which includes construction quality and design, impacts its value. Buyers should be mindful of these aspects for long-term satisfaction, while sellers should highlight these features in their marketing.

# %% [markdown]
# ---

# %% [markdown]
# # Exercises
#
# <p style='color:#5A5AE5'>We recommend you add exercises to your notebook, to help your learners apply what they have learned.</p>

# %%
# Optional (if exercises require datasets):

# !wget [url for dataset used in exercises]

# %% [markdown]
# ### Exercise 1 - Show the house 3 or more bedrooms

# %%
# Add code for exercise 1 here:
filtered_df = df[df['bedrooms'] >= 3]

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# filtered_df = df[df['bedrooms'] >= 3]
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2 - Set different parameters

# %% [markdown]
# Set different random forest model parameters to see if performance can increase. You can:
# - Try to add more and increase numbers of estimators
# - Try to add more `max_depth` values
# - Try to add parameters `min_samples_split` and `min_samples_leaf` in. You can set them with different values.\
# (note: set more parameters can significantly increase the grid search time)

# %%
# Add code for exercise 2 here:
param_randomf = {
    'n_estimators' : [100, 200, 300], # 'n_estimators' : nparrange[100, 400, 50],
    'max_depth': [1, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2]
}

# %% [markdown]
# <details>
#     <summary>Click here for a Hint</summary>
#
# ```python
# param_randomf = {
#     'n_estimators' : [100, 200, 300], # 'n_estimators' : nparrange[100, 400, 50],
#     'max_depth': [1, 5, 10],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2]
# }
# ```
# </details>

# %% [markdown]
# ### Exercise 3 - Change the estimator to XGboost

# %% [markdown]
# Content for Question 3

# %%
# Add code for exercise 3 here:
# !pip install xgboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 2.1 MB/s eta 0:00:0000:0100:01
# ...

# %%
import xgboost as xgb
xgb_regressor = xgb.XGBRegressor(
    objective='reg:squarederror',  # 'reg:squarederror' for regression
    colsample_bytree=0.8,
    learning_rate=0.1,
    max_depth=5,
    alpha=10,
    n_estimators=100  # Adjust the number of boosting rounds as needed
)

# Train the model
xgb_regressor.fit(X_train, y_train)

# Make predictions on the test set
y_pred = xgb_regressor.predict(X_test)

r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.8804941563927092

# %% [markdown]
# <details>
#     <summary>Click here for Hint</summary>
#
# <ol>
#     <li> Install xgboost first.
#     <li> Set appropriate parameters for xgboost.
#     <li> Change the estimator to xgboost regressor.
#
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# # Congratulations! You have completed the lab

# %% [markdown]
# ## Authors

# %% [markdown]
# [Kang Wang](https://author.skills.network/instructors/kang_wang)
#
# Kang Wang is a Data Scientist Intern in IBM. He is also a PhD Candidate in the University of Waterloo.

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# [Joseph Santarcangelo](https://author.skills.network/instructors/joseph_santarcangelo)
#
# Joseph has a Ph.D. in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# [Wojciech Fulmyk](https://author.skills.network/instructors/wojciech_fulmyk)
#
# I am a data scientist at the Ecosystems Skills Network at IBM, and an economics PhD candidate at the University of Calgary.

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-01-15|0.1|Kang Wang|Create the Project|

# %% [markdown]
# Copyright © 2023 IBM Corporation. All rights reserved.
